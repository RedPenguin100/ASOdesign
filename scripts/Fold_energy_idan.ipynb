# %%
from yehuda_code.rna_access import RNAAccess

# %%
# conda activate aso_design
import pandas
from scripts.data_genertion.consts import *
from asodesigner.file_utils import read_human_genome_fasta_dict
from asodesigner.consts import *
all_data = pandas.read_csv(DATA_PATH / 'data_from_article_fixed.csv')

# %%
all_data.head()
all_data.tail()
# Out:
#      ISIS Target_gene Cell_line  Density(cells/well) Transfection  \
# 0  540733       K-RAS      A431               5000.0  free uptake
# 1  540747       K-RAS      A431               5000.0  free uptake
# 2  540806       K-RAS      A431               5000.0  free uptake
# 3  651479       K-RAS      A431               5000.0  free uptake
# 4  651490       K-RAS      A431               5000.0  free uptake
#
#    ASO_volume(nM)  Treatment_Period(hours) Primer_probe_set          Sequence  \
# 0          2000.0                       24      RTS3496_MGB  GCTAAAACAAATGCTA
# 1          2000.0                       24      RTS3496_MGB  TATAATGGTGAATATC
# 2          2000.0                       24      RTS3496_MGB  GCATGAAGATTTCTGG
# 3          2000.0                       24      RTS3496_MGB  GGTGAATATCTTCAAA
# 4          2000.0                       24      RTS3496_MGB  CACTTGTACTAGTATG
#
#                   Modification               Location  Chemical_Pattern  \
# 0  cEt/5-methylcytosines/deoxy  0?1?2?13?14?15/C/else  CCCddddddddddCCC
# 1  cEt/5-methylcytosines/deoxy  0?1?2?13?14?15/C/else  CCCddddddddddCCC
# 2  cEt/5-methylcytosines/deoxy  0?1?2?13?14?15/C/else  CCCddddddddddCCC
# 3  cEt/5-methylcytosines/deoxy  0?1?2?13?14?15/C/else  CCCddddddddddCCC
# 4  cEt/5-methylcytosines/deoxy  0?1?2?13?14?15/C/else  CCCddddddddddCCC
#
#             Linkage Linkage_Location  \
# 0  phosphorothioate             else
# 1  phosphorothioate             else
# 2  phosphorothioate             else
# 3  phosphorothioate             else
# 4  phosphorothioate             else
#
#                                               Smiles  Inhibition(%)  \
# 0  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...           33.0
# 1  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@]34O[C@@...            7.0
# 2  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...           62.0
# 3  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...           28.0
# 4  Cc1cn([C@H]2C[C@H](OP(=O)([S-])[O]C[C@H]3O[C@@...           36.0
#
#    seq_length Canonical Gene Name Cell line organism
# 0          16                KRAS              human
# 1          16                KRAS              human
# 2          16                KRAS              human
# 3          16                KRAS              human
# 4          16                KRAS              human
